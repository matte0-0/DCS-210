# %% [markdown]
# <a href="https://colab.research.google.com/github/matte0-0/DCS-210/blob/main/hw2_Practicing_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### set-up

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("openintro")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘airports’, ‘cherryblossom’, ‘usdata’

# %%
library(tidyverse)
library(openintro)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.7      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: airports
#
# Loading required package: cherryblossom
#
# Loading required package: usdata

# %% [markdown]
# ## Questions 1-2
#
# 1. According to the data dictionary, how many pets are included in this dataset?
# 2. According to the data dictionary, how many variables do we have for each pet?

# %%
View(seattlepets)
# Out:
#       license_issue_date license_number animal_name     species
# 1     2018-11-16         8002756        Wall-E          Dog
# 2     2018-11-11         S124529        Andre           Dog
# 3     2018-11-21         903793         Mac             Dog
# 4     2018-11-23         824666         Melb            Cat
# 5     2018-12-30         S119138        Gingersnap      Cat
# 6     2018-12-16         S138529        Cody            Dog
# 7     2017-10-04         580652         Millie          Dog
# 8     2018-08-09         S142558        Sebastian       Cat
# 9     2018-08-20         S142546        Madeline        Cat
# 10    2018-12-08         S123830        Cleo            Cat
# 11    2018-12-23         961052         Sabre           Dog
# 12    2018-12-07         S125461        Thomas          Dog
# 13    2018-10-20         S149153        Glitch          Cat
# 14    2018-11-07         8002543        Lulu            Dog
# 15    2018-11-24         817137         Candy           Cat
# ...

# %% [markdown]
# My Answers
#
# 1. According to the data dictionary, there are 52,519 pets includded in this dataset.
# 2. According to the data dictionary, there are 7 variables for each pet.

# %% [markdown]
# ## Question 3
#
# 3. What are the three most common pet names in Seattle?

# %%
seattlepets %>%
  count(animal_name, sort = TRUE)
# Out:
#       animal_name           n
# 1     NA                    483
# 2     Lucy                  439
# 3     Charlie               387
# 4     Luna                  355
# 5     Bella                 331
# 6     Max                   270
# 7     Daisy                 261
# 8     Molly                 240
# 9     Jack                  232
# 10    Lily                  232
# 11    Stella                227
# 12    Lola                  225
# 13    Buddy                 218
# 14    Sophie                211
# 15    Oliver                210
# 16    Cooper                205
# 17    Maggie                201
# 18    Penny                 193
# 19    Ruby                  187
# 20    Sadie                 178
# 21    Chloe                 173
# 22    Milo                  172
# 23    Henry                 169
# 24    Rosie                 169
# 25    Pepper                164
# 26    Olive                 158
# 27    Bailey                157
# 28    Scout                 153
# ...

# %% [markdown]
# My Answers
#
# 3. The three most common pet names in Seattle are Lucy, Charlie, and Luna, with counts of 439, 387, and 355, respectively.

# %% [markdown]
# ## Question 4
#
# 4. Based on the previous output we can easily identify the most common cat and dog names in Seattle, but the output is sorted by n (the frequencies) as opposed to being organized by the species. Build on the pipeline to arrange the results so that they’re arranged by species first, and then n. This means you will need to add one more step to the pipeline, and you have two options: arrange(species, n) or arrange(n, species). You should try both and decide which one organizes the output by species and then ranks the names in order of frequency for each species.

# %%
seattlepets %>%
  group_by(species) %>%
  count(animal_name, sort=TRUE)
# Out:
#       species animal_name            n
# 1     Cat     NA                     406
# 2     Dog     Lucy                   337
# 3     Dog     Charlie                306
# 4     Dog     Bella                  249
# 5     Dog     Luna                   244
# 6     Dog     Daisy                  221
# 7     Dog     Cooper                 189
# 8     Dog     Lola                   187
# 9     Dog     Max                    186
# 10    Dog     Molly                  186
# 11    Dog     Stella                 185
# 12    Dog     Buddy                  175
# 13    Dog     Jack                   167
# 14    Dog     Maggie                 158
# 15    Dog     Penny                  153
# 16    Dog     Sadie                  153
# 17    Dog     Sophie                 152
# 18    Dog     Ruby                   150
# 19    Dog     Lily                   146
# 20    Dog     Rosie                  144
# 21    Dog     Bailey                 139
# 22    Dog     Oliver                 137
# ...

# %%
seattlepets %>%
  group_by(species) %>%
  count(animal_name, sort=TRUE) %>%
  slice_max(n, n = 5)
# Out:
#    species animal_name            n
# 1  Cat     NA                     406
# 2  Cat     Luna                   111
# 3  Cat     Lucy                   102
# 4  Cat     Lily                    86
# 5  Cat     Max                     83
# 6  Dog     Lucy                   337
# 7  Dog     Charlie                306
# 8  Dog     Bella                  249
# 9  Dog     Luna                   244
# 10 Dog     Daisy                  221
# 11 Goat    Heidi                    2
# 12 Goat    Abelard                  1
# 13 Goat    Aggie                    1
# 14 Goat    Arya                     1
# 15 Goat    Beans                    1
# 16 Goat    Brussels Sprout          1
# 17 Goat    Darcy                    1
# 18 Goat    Fawn                     1
# 19 Goat    Fiona                    1
# 20 Goat    Gavin                    1
# 21 Goat    Grace                    1
# 22 Goat    Grayson                  1
# 23 Goat    Holly                    1
# 24 Goat    Junebug                  1
# ...

# %%
seattlepets %>%
  group_by(species) %>%
  count(animal_name, sort=TRUE) %>%
  slice_max(n, n = 5) %>%
  arrange(species, desc(n))
# Out:
#    species animal_name            n
# 1  Cat     NA                     406
# 2  Cat     Luna                   111
# 3  Cat     Lucy                   102
# 4  Cat     Lily                    86
# 5  Cat     Max                     83
# 6  Dog     Lucy                   337
# 7  Dog     Charlie                306
# 8  Dog     Bella                  249
# 9  Dog     Luna                   244
# 10 Dog     Daisy                  221
# 11 Goat    Heidi                    2
# 12 Goat    Abelard                  1
# 13 Goat    Aggie                    1
# 14 Goat    Arya                     1
# 15 Goat    Beans                    1
# 16 Goat    Brussels Sprout          1
# 17 Goat    Darcy                    1
# 18 Goat    Fawn                     1
# 19 Goat    Fiona                    1
# 20 Goat    Gavin                    1
# 21 Goat    Grace                    1
# 22 Goat    Grayson                  1
# 23 Goat    Holly                    1
# 24 Goat    Junebug                  1
# ...

# %%
seattlepets %>%
  group_by(species) %>%
  count(animal_name, sort=TRUE) %>%
  slice_max(n, n = 5) %>%
  arrange(desc(n), species)
# Out:
#    species animal_name            n
# 1  Cat     NA                     406
# 2  Dog     Lucy                   337
# 3  Dog     Charlie                306
# 4  Dog     Bella                  249
# 5  Dog     Luna                   244
# 6  Dog     Daisy                  221
# 7  Cat     Luna                   111
# 8  Cat     Lucy                   102
# 9  Cat     Lily                    86
# 10 Cat     Max                     83
# 11 Goat    Heidi                    2
# 12 Goat    Abelard                  1
# 13 Goat    Aggie                    1
# 14 Goat    Arya                     1
# 15 Goat    Beans                    1
# 16 Goat    Brussels Sprout          1
# 17 Goat    Darcy                    1
# 18 Goat    Fawn                     1
# 19 Goat    Fiona                    1
# 20 Goat    Gavin                    1
# 21 Goat    Grace                    1
# 22 Goat    Grayson                  1
# 23 Goat    Holly                    1
# 24 Goat    Junebug                  1
# ...

# %% [markdown]
# My Answers
#
# 4. Of the two options, `arrange(species, n)` gave the desired output: organized by species, then ranked in order of frequency for each. *(Note: Unless I'm misunderstanding the prompt, I was already getting the desired output before adding the arrange line)*

# %% [markdown]
# ## Questions 5-6
#
# 5. What names are more common for cats than dogs? The ones above the line or the ones below the line?
# 6. Is the relationship between the two variables (proportion of cats with a given name and proportion of dogs with a given name) positive or negative? What does this mean in context of the data?

# %% [markdown]
# ![Cats_Dogs_Graph.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# My Answers
#
# 5. Names below the *x = y* line are more common for cats than for dogs, by proportion of total cats/dogs with each name.
# 6. The relationship between the two variables is positive. In this context, a positive correlation means that, generally, the more popular a name is for a cat the more popular it will be for a dog (or vice versa). This is pretty intuitive--the more popular a name is for any pet, the more popular it will be for all pets.
